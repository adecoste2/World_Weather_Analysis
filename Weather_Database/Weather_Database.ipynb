# %%
# Deliverable 1
# 1. Create a folder called Weather_Database.

# 2. Create a new Jupyter Notebook file to retrieve the weather data, and name it Weather_Database.ipynb.

# 3. Create a new set of 2,000 random latitudes and longitudes.

# 4. Get the nearest city using the citipy module.

# 5. Perform an API call with the OpenWeatherMap.

# 6. Retrieve the following information from the API call:
        #Latitude and longitude
        # Maximum temperature
        # Percent humidity
        # Percent cloudiness
        # Wind speed
        # Weather description (for example, clouds, fog, light rain, clear sky)
    
# 7. Add the data to a new DataFrame.

# 8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# %%
#Import our dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes.
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# 4. Get the nearest city using the citipy module.
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# 5. Perform an API call with the OpenWeatherMap.
url = f"http://api.openweathermap.org/data/2.5/weather?lat={lats}&lon={lngs}&units=imperial&appid=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?lat=[-27.27211963  -1.73397199 -21.54838927 ... -47.71709096  15.5331036
#  -25.02648289]&lon=[-147.86001842 -165.83724025   97.12874247 ... -165.06424772 -167.39980654
#     0.8100491 ]&units=imperial&appid=5246f387df9dddf5a7e15fb616f68bdc

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# 6. Retrieve the following information from the API call:
        #Latitude and longitude
        # Maximum temperature
        # Percent humidity
        # Percent cloudiness
        # Wind speed
        # Weather description (for example, clouds, fog, light rain, clear sky)
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
       
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 1 | carnarvon
# Processing Record 4 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 1 | saskylakh
# Processing Record 6 of Set 1 | luanda
# Processing Record 7 of Set 1 | broome
# Processing Record 8 of Set 1 | inza
# Processing Record 9 of Set 1 | mananjary
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | provideniya
# Processing Record 12 of Set 1 | yerbogachen
# Processing Record 13 of Set 1 | denpasar
# Processing Record 14 of Set 1 | svetlogorsk
# Processing Record 15 of Set 1 | shache
# Processing Record 16 of Set 1 | sosnovo-ozerskoye
# Processing Record 17 of Set 1 | portree
# Processing Record 18 of Set 1 | japura
# Processing Record 19 of Set 1 | hays
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | chokurdakh
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | shingu
# Processing Record 28 of Set 1 | rongcheng
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | codrington
# Processing Record 32 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | venlo
# Processing Record 35 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 1 | marsa matruh
# Processing Record 37 of Set 1 | asau
# Processing Record 38 of Set 1 | ancud
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | berlevag
# Processing Record 41 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 1 | mahanoro
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | waingapu
# Processing Record 46 of Set 1 | caxias
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | shelburne
# Processing Record 49 of Set 1 | owando
# Processing Record 50 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 2 | puerto madryn
# Processing Record 2 of Set 2 | santo domingo
# Processing Record 3 of Set 2 | quirinopolis
# Processing Record 4 of Set 2 | victoria
# Processing Record 5 of Set 2 | lubumbashi
# Processing Record 6 of Set 2 | rognan
# Processing Record 7 of Set 2 | makungu
# Processing Record 8 of Set 2 | castro
# Processing Record 9 of Set 2 | caravelas
# Processing Record 10 of Set 2 | general pico
# Processing Record 11 of Set 2 | severo-kurilsk
# Processing Record 12 of Set 2 | olga
# Processing Record 13 of Set 2 | chuy
# Processing Record 14 of Set 2 | haimen
# Processing Record 15 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 2 | bella union
# Processing Record 17 of Set 2 | banjar
# Processing Record 18 of Set 2 | yurla
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 2 | mehamn
# Processing Record 22 of Set 2 | sitka
# Processing Record 23 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 24 of Set 2 | hofn
# Processing Record 25 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 2 | namatanai
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | saldanha
# Processing Record 30 of Set 2 | tiarei
# Processing Record 31 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | bredasdorp
# Processing Record 34 of Set 2 | atasu
# Processing Record 35 of Set 2 | aklavik
# Processing Record 36 of Set 2 | dikson
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | san patricio
# Processing Record 39 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 2 | vostok
# Processing Record 41 of Set 2 | sharjah
# Processing Record 42 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 2 | ishinomaki
# Processing Record 44 of Set 2 | dargaville
# Processing Record 45 of Set 2 | cidreira
# Processing Record 46 of Set 2 | olafsvik
# Processing Record 47 of Set 2 | flinders
# Processing Record 48 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 2 | avarua
# Processing Record 50 of Set 2 | pochutla
# Processing Record 1 of Set 3 | ahipara
# Processing Record 2 of Set 3 | bengkulu
# Processing Record 3 of Set 3 | kaitangata
# Processing Record 4 of Set 3 | zeya
# Processing Record 5 of Set 3 | saquena
# Processing Record 6 of Set 3 | baboua
# City not found. Skipping...
# Processing Record 7 of Set 3 | rikitea
# Processing Record 8 of Set 3 | orotukan
# Processing Record 9 of Set 3 | porto novo
# Processing Record 10 of Set 3 | vila franca do campo
# Processing Record 11 of Set 3 | hasaki
# Processing Record 12 of Set 3 | new norfolk
# Processing Record 13 of Set 3 | usinsk
# Processing Record 14 of Set 3 | lesnoy
# Processing Record 15 of Set 3 | clyde river
# Processing Record 16 of Set 3 | sao filipe
# Processing Record 17 of Set 3 | matamoros
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | amarante do maranhao
# Processing Record 20 of Set 3 | arraial do cabo
# Processing Record 21 of Set 3 | saint-philippe
# Processing Record 22 of Set 3 | moranbah
# Processing Record 23 of Set 3 | punta arenas
# Processing Record 24 of Set 3 | bathsheba
# Processing Record 25 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 3 | at-bashi
# Processing Record 27 of Set 3 | cherskiy
# Processing Record 28 of Set 3 | saint george
# Processing Record 29 of Set 3 | yar-sale
# Processing Record 30 of Set 3 | adrar
# Processing Record 31 of Set 3 | longyearbyen
# Processing Record 32 of Set 3 | solnechnyy
# Processing Record 33 of Set 3 | mount gambier
# Processing Record 34 of Set 3 | la libertad
# Processing Record 35 of Set 3 | navirai
# Processing Record 36 of Set 3 | rocha
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 3 | asyut
# Processing Record 41 of Set 3 | bluff
# Processing Record 42 of Set 3 | faanui
# Processing Record 43 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 3 | kulu
# Processing Record 45 of Set 3 | nelson bay
# Processing Record 46 of Set 3 | port lincoln
# Processing Record 47 of Set 3 | nueva loja
# Processing Record 48 of Set 3 | vaini
# Processing Record 49 of Set 3 | sao jose da coroa grande
# Processing Record 50 of Set 3 | bethel
# Processing Record 1 of Set 4 | sabang
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | atar
# Processing Record 4 of Set 4 | barrow
# Processing Record 5 of Set 4 | airai
# Processing Record 6 of Set 4 | taltal
# Processing Record 7 of Set 4 | tuktoyaktuk
# Processing Record 8 of Set 4 | bara
# Processing Record 9 of Set 4 | cap-aux-meules
# Processing Record 10 of Set 4 | evensk
# Processing Record 11 of Set 4 | zaysan
# Processing Record 12 of Set 4 | deder
# Processing Record 13 of Set 4 | werda
# Processing Record 14 of Set 4 | kualakapuas
# Processing Record 15 of Set 4 | lorengau
# Processing Record 16 of Set 4 | krasnoslobodsk
# Processing Record 17 of Set 4 | atuona
# Processing Record 18 of Set 4 | torbay
# Processing Record 19 of Set 4 | mount isa
# Processing Record 20 of Set 4 | bambous virieux
# Processing Record 21 of Set 4 | yekaterinoslavka
# Processing Record 22 of Set 4 | kruisfontein
# Processing Record 23 of Set 4 | pevek
# Processing Record 24 of Set 4 | fortuna
# Processing Record 25 of Set 4 | cabo san lucas
# Processing Record 26 of Set 4 | thompson
# Processing Record 27 of Set 4 | tasiilaq
# Processing Record 28 of Set 4 | tahoua
# Processing Record 29 of Set 4 | mecca
# Processing Record 30 of Set 4 | kamareddi
# Processing Record 31 of Set 4 | isangel
# Processing Record 32 of Set 4 | constitucion
# Processing Record 33 of Set 4 | aksu
# Processing Record 34 of Set 4 | toora-khem
# Processing Record 35 of Set 4 | piacabucu
# Processing Record 36 of Set 4 | pangkalanbuun
# Processing Record 37 of Set 4 | kidal
# Processing Record 38 of Set 4 | dingle
# Processing Record 39 of Set 4 | ossora
# Processing Record 40 of Set 4 | ulaanbaatar
# Processing Record 41 of Set 4 | yulara
# Processing Record 42 of Set 4 | biak
# Processing Record 43 of Set 4 | anadyr
# Processing Record 44 of Set 4 | posse
# Processing Record 45 of Set 4 | dukat
# Processing Record 46 of Set 4 | slave lake
# Processing Record 47 of Set 4 | dalbandin
# Processing Record 48 of Set 4 | felipe carrillo puerto
# Processing Record 49 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 4 | okitipupa
# Processing Record 1 of Set 5 | bendigo
# Processing Record 2 of Set 5 | tighina
# Processing Record 3 of Set 5 | bubaque
# Processing Record 4 of Set 5 | marawi
# Processing Record 5 of Set 5 | nanortalik
# Processing Record 6 of Set 5 | lakes entrance
# Processing Record 7 of Set 5 | katsuura
# Processing Record 8 of Set 5 | middle island
# Processing Record 9 of Set 5 | bud
# Processing Record 10 of Set 5 | ouadda
# Processing Record 11 of Set 5 | gumia
# Processing Record 12 of Set 5 | vozhega
# Processing Record 13 of Set 5 | mayo
# Processing Record 14 of Set 5 | vila velha
# Processing Record 15 of Set 5 | riverdale
# Processing Record 16 of Set 5 | nouadhibou
# Processing Record 17 of Set 5 | faya
# Processing Record 18 of Set 5 | oktyabrskoye
# Processing Record 19 of Set 5 | mahebourg
# Processing Record 20 of Set 5 | honningsvag
# Processing Record 21 of Set 5 | tual
# Processing Record 22 of Set 5 | geraldton
# Processing Record 23 of Set 5 | poso
# Processing Record 24 of Set 5 | castres
# Processing Record 25 of Set 5 | pisco
# Processing Record 26 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 5 | dalnegorsk
# Processing Record 28 of Set 5 | fort nelson
# Processing Record 29 of Set 5 | phangnga
# Processing Record 30 of Set 5 | araouane
# Processing Record 31 of Set 5 | huangchuan
# Processing Record 32 of Set 5 | verkhovazhye
# Processing Record 33 of Set 5 | port elizabeth
# Processing Record 34 of Set 5 | cozumel
# Processing Record 35 of Set 5 | saint-joseph
# Processing Record 36 of Set 5 | hilo
# Processing Record 37 of Set 5 | ust-ordynskiy
# Processing Record 38 of Set 5 | esperance
# Processing Record 39 of Set 5 | arlit
# Processing Record 40 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 41 of Set 5 | mashhad
# Processing Record 42 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 43 of Set 5 | ilulissat
# Processing Record 44 of Set 5 | tezu
# Processing Record 45 of Set 5 | lodja
# Processing Record 46 of Set 5 | dunedin
# Processing Record 47 of Set 5 | husavik
# Processing Record 48 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 5 | narsaq
# Processing Record 50 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 6 | korla
# Processing Record 2 of Set 6 | isiro
# Processing Record 3 of Set 6 | kiruna
# Processing Record 4 of Set 6 | east london
# Processing Record 5 of Set 6 | cimitarra
# Processing Record 6 of Set 6 | rawson
# Processing Record 7 of Set 6 | bustonkala
# City not found. Skipping...
# Processing Record 8 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 6 | iqaluit
# Processing Record 10 of Set 6 | klaksvik
# Processing Record 11 of Set 6 | tombouctou
# Processing Record 12 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 6 | gaya
# Processing Record 14 of Set 6 | miri
# Processing Record 15 of Set 6 | talnakh
# Processing Record 16 of Set 6 | los llanos de aridane
# Processing Record 17 of Set 6 | coquimbo
# Processing Record 18 of Set 6 | ulladulla
# Processing Record 19 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 6 | san quintin
# Processing Record 21 of Set 6 | camana
# Processing Record 22 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 23 of Set 6 | luwuk
# Processing Record 24 of Set 6 | sangamner
# Processing Record 25 of Set 6 | avera
# Processing Record 26 of Set 6 | nueva londres
# Processing Record 27 of Set 6 | uva
# Processing Record 28 of Set 6 | binga
# Processing Record 29 of Set 6 | chibombo
# Processing Record 30 of Set 6 | camacari
# Processing Record 31 of Set 6 | benguela
# Processing Record 32 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 33 of Set 6 | tuatapere
# Processing Record 34 of Set 6 | malatya
# Processing Record 35 of Set 6 | port alfred
# Processing Record 36 of Set 6 | ketchikan
# Processing Record 37 of Set 6 | tariba
# Processing Record 38 of Set 6 | labuhan
# Processing Record 39 of Set 6 | comodoro rivadavia
# Processing Record 40 of Set 6 | dieppe
# Processing Record 41 of Set 6 | kavaratti
# Processing Record 42 of Set 6 | port hardy
# Processing Record 43 of Set 6 | san miguel
# Processing Record 44 of Set 6 | alice springs
# Processing Record 45 of Set 6 | dawlatabad
# Processing Record 46 of Set 6 | hutang
# Processing Record 47 of Set 6 | lompoc
# Processing Record 48 of Set 6 | antalaha
# Processing Record 49 of Set 6 | bilibino
# Processing Record 50 of Set 6 | mulege
# Processing Record 1 of Set 7 | matagalpa
# Processing Record 2 of Set 7 | tecoanapa
# Processing Record 3 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 7 | chivilcoy
# Processing Record 5 of Set 7 | karimganj
# Processing Record 6 of Set 7 | atakpame
# Processing Record 7 of Set 7 | qandala
# Processing Record 8 of Set 7 | marang
# Processing Record 9 of Set 7 | lexington
# Processing Record 10 of Set 7 | zhigansk
# Processing Record 11 of Set 7 | palafrugell
# Processing Record 12 of Set 7 | hamilton
# Processing Record 13 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 7 | qui nhon
# Processing Record 15 of Set 7 | morondava
# Processing Record 16 of Set 7 | pacific grove
# Processing Record 17 of Set 7 | abnub
# Processing Record 18 of Set 7 | haines junction
# Processing Record 19 of Set 7 | lebu
# Processing Record 20 of Set 7 | zonguldak
# Processing Record 21 of Set 7 | sundargarh
# Processing Record 22 of Set 7 | bac lieu
# Processing Record 23 of Set 7 | tartki
# City not found. Skipping...
# Processing Record 24 of Set 7 | brae
# Processing Record 25 of Set 7 | gharo
# Processing Record 26 of Set 7 | hyeres
# Processing Record 27 of Set 7 | charters towers
# Processing Record 28 of Set 7 | saint-ambroise
# Processing Record 29 of Set 7 | soften
# Processing Record 30 of Set 7 | opuwo
# Processing Record 31 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 7 | muroto
# Processing Record 33 of Set 7 | venice
# Processing Record 34 of Set 7 | sahbuz
# Processing Record 35 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 7 | ballina
# Processing Record 37 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 7 | jerome
# Processing Record 39 of Set 7 | tuy hoa
# Processing Record 40 of Set 7 | ilheus
# Processing Record 41 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 7 | touros
# Processing Record 43 of Set 7 | dinar
# Processing Record 44 of Set 7 | aasiaat
# Processing Record 45 of Set 7 | tiksi
# Processing Record 46 of Set 7 | mae sai
# Processing Record 47 of Set 7 | hithadhoo
# Processing Record 48 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 49 of Set 7 | seybaplaya
# Processing Record 50 of Set 7 | westport
# Processing Record 1 of Set 8 | kamenka
# Processing Record 2 of Set 8 | riberalta
# Processing Record 3 of Set 8 | harper
# Processing Record 4 of Set 8 | sechura
# Processing Record 5 of Set 8 | ust-maya
# Processing Record 6 of Set 8 | lae
# Processing Record 7 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 8 of Set 8 | mazagao
# Processing Record 9 of Set 8 | viedma
# Processing Record 10 of Set 8 | lavrentiya
# Processing Record 11 of Set 8 | lubango
# Processing Record 12 of Set 8 | garissa
# Processing Record 13 of Set 8 | brigham city
# Processing Record 14 of Set 8 | lincoln
# Processing Record 15 of Set 8 | datong
# Processing Record 16 of Set 8 | panaba
# Processing Record 17 of Set 8 | kimbe
# Processing Record 18 of Set 8 | waipawa
# Processing Record 19 of Set 8 | tongliao
# Processing Record 20 of Set 8 | cache creek
# Processing Record 21 of Set 8 | goba
# Processing Record 22 of Set 8 | inta
# Processing Record 23 of Set 8 | lata
# Processing Record 24 of Set 8 | san cristobal
# Processing Record 25 of Set 8 | kapit
# Processing Record 26 of Set 8 | erenhot
# Processing Record 27 of Set 8 | scicli
# Processing Record 28 of Set 8 | vallenar
# Processing Record 29 of Set 8 | erzin
# Processing Record 30 of Set 8 | dalvik
# Processing Record 31 of Set 8 | mokhsogollokh
# Processing Record 32 of Set 8 | praia da vitoria
# Processing Record 33 of Set 8 | san angelo
# Processing Record 34 of Set 8 | caloundra
# Processing Record 35 of Set 8 | diapaga
# Processing Record 36 of Set 8 | riyadh
# Processing Record 37 of Set 8 | kavieng
# Processing Record 38 of Set 8 | bandarbeyla
# Processing Record 39 of Set 8 | pangnirtung
# Processing Record 40 of Set 8 | moose factory
# Processing Record 41 of Set 8 | giyani
# Processing Record 42 of Set 8 | gushikawa
# Processing Record 43 of Set 8 | khatanga
# Processing Record 44 of Set 8 | gudibanda
# Processing Record 45 of Set 8 | otradnoye
# Processing Record 46 of Set 8 | noumea
# Processing Record 47 of Set 8 | sao paulo de olivenca
# Processing Record 48 of Set 8 | fort morgan
# Processing Record 49 of Set 8 | lagos
# Processing Record 50 of Set 8 | bartica
# Processing Record 1 of Set 9 | emerald
# Processing Record 2 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 3 of Set 9 | jumla
# Processing Record 4 of Set 9 | humaita
# Processing Record 5 of Set 9 | arrecife
# Processing Record 6 of Set 9 | ihosy
# Processing Record 7 of Set 9 | andenes
# Processing Record 8 of Set 9 | camabatela
# Processing Record 9 of Set 9 | oktyabrskiy
# Processing Record 10 of Set 9 | muros
# Processing Record 11 of Set 9 | potosi
# Processing Record 12 of Set 9 | kajaani
# Processing Record 13 of Set 9 | port macquarie
# Processing Record 14 of Set 9 | curumani
# Processing Record 15 of Set 9 | aldan
# Processing Record 16 of Set 9 | guerrero negro
# Processing Record 17 of Set 9 | warrnambool
# Processing Record 18 of Set 9 | ponta do sol
# Processing Record 19 of Set 9 | salalah
# Processing Record 20 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 9 | kotelnikovo
# Processing Record 22 of Set 9 | asahi
# Processing Record 23 of Set 9 | norman wells
# Processing Record 24 of Set 9 | namibe
# Processing Record 25 of Set 9 | bo
# City not found. Skipping...
# Processing Record 26 of Set 9 | sao joao da barra
# Processing Record 27 of Set 9 | torit
# Processing Record 28 of Set 9 | chulman
# Processing Record 29 of Set 9 | college
# Processing Record 30 of Set 9 | plettenberg bay
# Processing Record 31 of Set 9 | dorolt
# Processing Record 32 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 9 | artigas
# Processing Record 34 of Set 9 | lima
# Processing Record 35 of Set 9 | kloulklubed
# Processing Record 36 of Set 9 | cornwall
# Processing Record 37 of Set 9 | cap malheureux
# Processing Record 38 of Set 9 | north battleford
# Processing Record 39 of Set 9 | morgan city
# Processing Record 40 of Set 9 | terme
# Processing Record 41 of Set 9 | topolovatu mare
# Processing Record 42 of Set 9 | susanville
# Processing Record 43 of Set 9 | prince rupert
# Processing Record 44 of Set 9 | padang
# Processing Record 45 of Set 9 | sungaipenuh
# Processing Record 46 of Set 9 | inawashiro
# Processing Record 47 of Set 9 | duldurga
# Processing Record 48 of Set 9 | belmonte
# Processing Record 49 of Set 9 | parsons
# Processing Record 50 of Set 9 | sibolga
# Processing Record 1 of Set 10 | haukipudas
# Processing Record 2 of Set 10 | leningradskiy
# Processing Record 3 of Set 10 | neulengbach
# Processing Record 4 of Set 10 | souillac
# Processing Record 5 of Set 10 | mocuba
# Processing Record 6 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 7 of Set 10 | hereford
# Processing Record 8 of Set 10 | karla
# Processing Record 9 of Set 10 | pryozerne
# Processing Record 10 of Set 10 | zhezkazgan
# Processing Record 11 of Set 10 | santa maria
# Processing Record 12 of Set 10 | black river
# Processing Record 13 of Set 10 | madrid
# Processing Record 14 of Set 10 | nantucket
# Processing Record 15 of Set 10 | newport news
# Processing Record 16 of Set 10 | rodniki
# Processing Record 17 of Set 10 | inuvik
# Processing Record 18 of Set 10 | half moon bay
# Processing Record 19 of Set 10 | abong mbang
# Processing Record 20 of Set 10 | pryluky
# Processing Record 21 of Set 10 | thunder bay
# Processing Record 22 of Set 10 | ostrovnoy
# Processing Record 23 of Set 10 | cockburn town
# Processing Record 24 of Set 10 | san juan de los morros
# Processing Record 25 of Set 10 | port blair
# Processing Record 26 of Set 10 | batagay-alyta
# Processing Record 27 of Set 10 | peniche
# Processing Record 28 of Set 10 | aracaju
# Processing Record 29 of Set 10 | boulsa
# Processing Record 30 of Set 10 | qaqortoq
# Processing Record 31 of Set 10 | montrose
# Processing Record 32 of Set 10 | palu
# Processing Record 33 of Set 10 | am timan
# Processing Record 34 of Set 10 | barsovo
# Processing Record 35 of Set 10 | koran
# Processing Record 36 of Set 10 | samarai
# Processing Record 37 of Set 10 | murupara
# Processing Record 38 of Set 10 | sainte-anne-des-monts
# Processing Record 39 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 10 | tazovskiy
# Processing Record 41 of Set 10 | roebourne
# Processing Record 42 of Set 10 | ikwiriri
# Processing Record 43 of Set 10 | manacor
# Processing Record 44 of Set 10 | san jeronimo
# Processing Record 45 of Set 10 | naryan-mar
# Processing Record 46 of Set 10 | ulaangom
# Processing Record 47 of Set 10 | fairbanks
# Processing Record 48 of Set 10 | rio gallegos
# Processing Record 49 of Set 10 | pitiquito
# Processing Record 50 of Set 10 | krasnoselkup
# Processing Record 1 of Set 11 | nurota
# Processing Record 2 of Set 11 | petauke
# Processing Record 3 of Set 11 | chapais
# Processing Record 4 of Set 11 | progreso
# Processing Record 5 of Set 11 | oeiras
# Processing Record 6 of Set 11 | sabha
# Processing Record 7 of Set 11 | da nang
# Processing Record 8 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 11 | taunsa
# Processing Record 10 of Set 11 | pangai
# Processing Record 11 of Set 11 | sivaki
# Processing Record 12 of Set 11 | xining
# Processing Record 13 of Set 11 | karratha
# Processing Record 14 of Set 11 | plastun
# Processing Record 15 of Set 11 | bikin
# Processing Record 16 of Set 11 | gorom-gorom
# Processing Record 17 of Set 11 | shorkot
# Processing Record 18 of Set 11 | bousso
# Processing Record 19 of Set 11 | tyukhtet
# Processing Record 20 of Set 11 | huarmey
# Processing Record 21 of Set 11 | napanee
# Processing Record 22 of Set 11 | nara
# Processing Record 23 of Set 11 | envira
# Processing Record 24 of Set 11 | port hedland
# Processing Record 25 of Set 11 | coihaique
# Processing Record 26 of Set 11 | oranjemund
# Processing Record 27 of Set 11 | lamont
# Processing Record 28 of Set 11 | sakakah
# Processing Record 29 of Set 11 | marystown
# Processing Record 30 of Set 11 | alice
# Processing Record 31 of Set 11 | anahuac
# Processing Record 32 of Set 11 | beloha
# Processing Record 33 of Set 11 | maragogi
# Processing Record 34 of Set 11 | vestbygda
# City not found. Skipping...
# Processing Record 35 of Set 11 | gamba
# Processing Record 36 of Set 11 | toila
# Processing Record 37 of Set 11 | vieques
# Processing Record 38 of Set 11 | jibuti
# Processing Record 39 of Set 11 | okha
# Processing Record 40 of Set 11 | nanakuli
# Processing Record 41 of Set 11 | valparaiso
# Processing Record 42 of Set 11 | garowe
# Processing Record 43 of Set 11 | todos santos
# Processing Record 44 of Set 11 | kurilsk
# Processing Record 45 of Set 11 | tikrit
# Processing Record 46 of Set 11 | shikhany
# Processing Record 47 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 48 of Set 11 | narrabri
# Processing Record 49 of Set 11 | nyurba
# Processing Record 50 of Set 11 | novi di modena
# Processing Record 1 of Set 12 | lewiston
# Processing Record 2 of Set 12 | dawson creek
# Processing Record 3 of Set 12 | lagoa
# Processing Record 4 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 5 of Set 12 | esmeraldas
# Processing Record 6 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 12 | changji
# Processing Record 8 of Set 12 | kapuskasing
# Processing Record 9 of Set 12 | laguna
# Processing Record 10 of Set 12 | klaebu
# Processing Record 11 of Set 12 | omsukchan
# Processing Record 12 of Set 12 | cowra
# Processing Record 13 of Set 12 | kpandu
# Processing Record 14 of Set 12 | sterling
# Processing Record 15 of Set 12 | ochakiv
# Processing Record 16 of Set 12 | nivala
# Processing Record 17 of Set 12 | chanderi
# Processing Record 18 of Set 12 | deputatskiy
# Processing Record 19 of Set 12 | dongsheng
# Processing Record 20 of Set 12 | buritis
# Processing Record 21 of Set 12 | falaleu
# City not found. Skipping...
# Processing Record 22 of Set 12 | vestmannaeyjar
# Processing Record 23 of Set 12 | newport
# Processing Record 24 of Set 12 | odweyne
# Processing Record 25 of Set 12 | vao
# Processing Record 26 of Set 12 | la reforma
# Processing Record 27 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 28 of Set 12 | doha
# Processing Record 29 of Set 12 | asbe teferi
# Processing Record 30 of Set 12 | pietarsaari
# Processing Record 31 of Set 12 | kupang
# Processing Record 32 of Set 12 | verkh-usugli
# Processing Record 33 of Set 12 | oum hadjer
# Processing Record 34 of Set 12 | jinchang
# Processing Record 35 of Set 12 | uige
# Processing Record 36 of Set 12 | mahenge
# Processing Record 37 of Set 12 | abu kamal
# Processing Record 38 of Set 12 | atambua
# Processing Record 39 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 40 of Set 12 | puerto maldonado
# Processing Record 41 of Set 12 | kahului
# Processing Record 42 of Set 12 | grand gaube
# Processing Record 43 of Set 12 | makakilo city
# Processing Record 44 of Set 12 | bakchar
# Processing Record 45 of Set 12 | fontanka
# Processing Record 46 of Set 12 | sri aman
# Processing Record 47 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 48 of Set 12 | beyneu
# Processing Record 49 of Set 12 | sijunjung
# Processing Record 50 of Set 12 | alofi
# Processing Record 1 of Set 13 | yelan
# Processing Record 2 of Set 13 | pinawa
# Processing Record 3 of Set 13 | arman
# Processing Record 4 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 5 of Set 13 | san carlos
# Processing Record 6 of Set 13 | pergamino
# Processing Record 7 of Set 13 | okato
# Processing Record 8 of Set 13 | druzhba
# Processing Record 9 of Set 13 | kem
# Processing Record 10 of Set 13 | nakapiripirit
# Processing Record 11 of Set 13 | the valley
# Processing Record 12 of Set 13 | teahupoo
# Processing Record 13 of Set 13 | hobyo
# Processing Record 14 of Set 13 | dombarovskiy
# Processing Record 15 of Set 13 | mamburao
# Processing Record 16 of Set 13 | mao
# Processing Record 17 of Set 13 | takoradi
# Processing Record 18 of Set 13 | ciudad bolivar
# Processing Record 19 of Set 13 | yenagoa
# Processing Record 20 of Set 13 | kaeo
# Processing Record 21 of Set 13 | chernyshevsk
# Processing Record 22 of Set 13 | ciamis
# Processing Record 23 of Set 13 | kieta
# Processing Record 24 of Set 13 | tommot
# Processing Record 25 of Set 13 | bonavista
# Processing Record 26 of Set 13 | acajutla
# Processing Record 27 of Set 13 | tateyama
# Processing Record 28 of Set 13 | aksha
# Processing Record 29 of Set 13 | rio grande
# Processing Record 30 of Set 13 | meulaboh
# Processing Record 31 of Set 13 | kashi
# Processing Record 32 of Set 13 | pedernales
# Processing Record 33 of Set 13 | bosaso
# Processing Record 34 of Set 13 | khani
# Processing Record 35 of Set 13 | rumoi
# Processing Record 36 of Set 13 | flagstaff
# Processing Record 37 of Set 13 | manoel urbano
# Processing Record 38 of Set 13 | mandvi
# Processing Record 39 of Set 13 | uvinza
# Processing Record 40 of Set 13 | buala
# Processing Record 41 of Set 13 | pathein
# Processing Record 42 of Set 13 | cabudare
# Processing Record 43 of Set 13 | poyarkovo
# Processing Record 44 of Set 13 | cabedelo
# Processing Record 45 of Set 13 | stekolnyy
# City not found. Skipping...
# Processing Record 46 of Set 13 | hit
# Processing Record 47 of Set 13 | maraa
# Processing Record 48 of Set 13 | minna
# Processing Record 49 of Set 13 | jalu
# Processing Record 50 of Set 13 | maridi
# Processing Record 1 of Set 14 | pilar
# Processing Record 2 of Set 14 | ishigaki
# Processing Record 3 of Set 14 | majene
# Processing Record 4 of Set 14 | nizhniy kuranakh
# Processing Record 5 of Set 14 | najran
# Processing Record 6 of Set 14 | parabel
# Processing Record 7 of Set 14 | indramayu
# Processing Record 8 of Set 14 | camacha
# Processing Record 9 of Set 14 | poroshkovo
# Processing Record 10 of Set 14 | kerrville
# Processing Record 11 of Set 14 | nome
# Processing Record 12 of Set 14 | kaputa
# Processing Record 13 of Set 14 | benjamin constant
# Processing Record 14 of Set 14 | mogadishu
# Processing Record 15 of Set 14 | shahr-e babak
# Processing Record 16 of Set 14 | udachnyy
# Processing Record 17 of Set 14 | carnduff
# Processing Record 18 of Set 14 | zakharovo
# Processing Record 19 of Set 14 | yilan
# Processing Record 20 of Set 14 | hoi an
# Processing Record 21 of Set 14 | canico
# Processing Record 22 of Set 14 | jinji
# Processing Record 23 of Set 14 | lundazi
# Processing Record 24 of Set 14 | puerto padre
# Processing Record 25 of Set 14 | ryotsu
# Processing Record 26 of Set 14 | koumac
# Processing Record 27 of Set 14 | lerwick
# Processing Record 28 of Set 14 | egvekinot
# Processing Record 29 of Set 14 | saint anthony
# Processing Record 30 of Set 14 | hirara
# Processing Record 31 of Set 14 | semey
# Processing Record 32 of Set 14 | tairua
# Processing Record 33 of Set 14 | jamiltepec
# Processing Record 34 of Set 14 | puerto escondido
# Processing Record 35 of Set 14 | minas
# Processing Record 36 of Set 14 | nizwa
# Processing Record 37 of Set 14 | severomuysk
# Processing Record 38 of Set 14 | yinchuan
# Processing Record 39 of Set 14 | cartagena del chaira
# Processing Record 40 of Set 14 | redmond
# Processing Record 41 of Set 14 | nalut
# Processing Record 42 of Set 14 | ayan
# Processing Record 43 of Set 14 | sao domingos do maranhao
# Processing Record 44 of Set 14 | boyolangu
# Processing Record 45 of Set 14 | bundaberg
# Processing Record 46 of Set 14 | san jose
# Processing Record 47 of Set 14 | novodzherelievskaya
# City not found. Skipping...
# Processing Record 48 of Set 14 | kutum
# Processing Record 49 of Set 14 | sumbe
# Processing Record 50 of Set 14 | birin
# Processing Record 1 of Set 15 | juba
# Processing Record 2 of Set 15 | havoysund
# Processing Record 3 of Set 15 | iskateley
# Processing Record 4 of Set 15 | las tunas
# Processing Record 5 of Set 15 | anzio
# Processing Record 6 of Set 15 | gizo
# Processing Record 7 of Set 15 | serenje
# Processing Record 8 of Set 15 | rosarito
# Processing Record 9 of Set 15 | amapa
# Processing Record 10 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 15 | tevaitoa
# Processing Record 12 of Set 15 | bima
# Processing Record 13 of Set 15 | urumqi
# Processing Record 14 of Set 15 | neaua
# Processing Record 15 of Set 15 | mokshan
# Processing Record 16 of Set 15 | ngunguru
# Processing Record 17 of Set 15 | syamzha
# Processing Record 18 of Set 15 | banda aceh
# Processing Record 19 of Set 15 | pemba
# Processing Record 20 of Set 15 | paamiut
# Processing Record 21 of Set 15 | el tambo
# Processing Record 22 of Set 15 | komsomolskiy
# Processing Record 23 of Set 15 | cervo
# Processing Record 24 of Set 15 | alta floresta
# Processing Record 25 of Set 15 | gusev
# Processing Record 26 of Set 15 | amahai
# Processing Record 27 of Set 15 | winslow
# Processing Record 28 of Set 15 | acapulco
# Processing Record 29 of Set 15 | sillamae
# Processing Record 30 of Set 15 | virginia beach
# Processing Record 31 of Set 15 | quatre cocos
# Processing Record 32 of Set 15 | mayumba
# Processing Record 33 of Set 15 | baruun-urt
# Processing Record 34 of Set 15 | morant bay
# Processing Record 35 of Set 15 | balkhash
# Processing Record 36 of Set 15 | sarnia
# Processing Record 37 of Set 15 | zhanaozen
# Processing Record 38 of Set 15 | nuuk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 677

# %%
# 7. Add the data to a new DataFrame.
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

#Reorder columns as City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed and Current Description
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# Display the DataFrame
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     62.47        65         100
# 1     Carnarvon      AU -24.8667  113.6333     75.27        88           0
# 2     Saskylakh      RU  71.9167  114.0833    -34.37       100          98
# 3        Luanda      AO  -8.8368   13.2343     79.97        81          85
# 4        Broome      US  42.2506  -75.8330     43.66        64           0
# 5          Inza      RU  53.8533   46.3586      7.12        92          93
# 6     Mananjary      MG -21.2167   48.3333     75.24        92          98
# 7  Puerto Ayora      EC  -0.7393  -90.3518     82.36        85          72
# 8   Provideniya      RU  64.3833 -173.3000     19.51        68           0
# 9   Yerbogachen      RU  61.2767  108.0108    -15.79        99          83
#
#    Wind Speed Current Description
# 0        5.28     overcast clouds
# 1        6.91           clear sky
# 2        3.74     overcast clouds
# 3       10.71     overcast clouds
# 4        1.99           clear sky
# 5       11.21     overcast clouds
# 6        2.68          light rain
# 7        5.99       broken clouds
# 8       38.01           clear sky
# 9        6.38       broken clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
